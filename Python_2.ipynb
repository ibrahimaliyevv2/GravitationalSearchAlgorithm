# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot

# %%
# reading all the experiment files that includes info about best fitnesses
ackley = pd.read_csv('experiment_ackley.csv')
rastrigin = pd.read_csv('experiment_rastrigin.csv')
rosenbrock = pd.read_csv('experiment_rosenbrock.csv')
schwefel = pd.read_csv('experiment_schwefel.csv')

# %%
# show 1st 5 rows
ackley.head()
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-50-41  2022-12-12-00-50-42       0.760316
#
#            Iter1          Iter2  Iter3  Iter4  Iter5  ...  Iter21  Iter22  \
# 0 -2.963927e+137 -1.178570e+246   -inf   -inf   -inf  ...    -inf    -inf
#
#    Iter23  Iter24  Iter25  Iter26  Iter27  Iter28  Iter29  Iter30
# 0    -inf    -inf    -inf    -inf    -inf    -inf    -inf    -inf
#
# [1 rows x 35 columns]

# %%
rastrigin.head()
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-45-18  2022-12-12-00-45-19       0.977116
#
#        Iter1      Iter2      Iter3     Iter4      Iter5  ...    Iter21  \
# 0  166.92644  166.92644  145.32676 -6.088595 -16.791439  ... -50.40853
#
#      Iter22    Iter23    Iter24    Iter25    Iter26    Iter27    Iter28  \
# 0 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853
#
#      Iter29    Iter30
# 0 -50.40853 -50.40853
#
# [1 rows x 35 columns]

# %%
rosenbrock.head()
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-52-50  2022-12-12-00-52-51       0.875708
#
#           Iter1         Iter2         Iter3         Iter4         Iter5  ...  \
# 0  2.633843e+10  1.563447e+10  7.941227e+09  5.279988e+09  3.926489e+09  ...
#
#          Iter21        Iter22        Iter23        Iter24        Iter25  \
# 0  2.540964e+09  2.540917e+09  2.540888e+09  2.540872e+09  2.540865e+09
#
#          Iter26        Iter27        Iter28        Iter29        Iter30
# 0  2.540859e+09  2.540857e+09  2.540856e+09  2.540855e+09  2.540855e+09
#
# [1 rows x 35 columns]

# %%
schwefel.head()
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-51-48  2022-12-12-00-51-49       0.932205
#
#         Iter1       Iter2       Iter3       Iter4        Iter5  ...  \
# 0 -1661.66041 -1661.66041 -1661.66041 -1661.66041 -1661.833559  ...
#
#         Iter21       Iter22       Iter23       Iter24       Iter25  \
# 0 -1724.566212 -1724.566212 -1724.566212 -1724.566212 -1724.566212
#
#         Iter26       Iter27       Iter28       Iter29       Iter30
# 0 -1724.566212 -1724.566212 -1724.566212 -1724.566212 -1724.566212
#
# [1 rows x 35 columns]

# %%
# specifying columns that we want to delete
attr = ['Optimizer', 'objfname', 'startTime', 'EndTime', 'ExecutionTime']

# %%
ackley
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-50-41  2022-12-12-00-50-42       0.760316
#
#            Iter1          Iter2  Iter3  Iter4  Iter5  ...  Iter21  Iter22  \
# 0 -2.963927e+137 -1.178570e+246   -inf   -inf   -inf  ...    -inf    -inf
#
#    Iter23  Iter24  Iter25  Iter26  Iter27  Iter28  Iter29  Iter30
# 0    -inf    -inf    -inf    -inf    -inf    -inf    -inf    -inf
#
# [1 rows x 35 columns]

# %%
# delete columns that is chosen in the attr list
ackley.drop(attr,inplace=True,axis=1)

# %%
ackley
# Out:
#            Iter1          Iter2  Iter3  Iter4  Iter5  Iter6  Iter7  Iter8  \
# 0 -2.963927e+137 -1.178570e+246   -inf   -inf   -inf   -inf   -inf   -inf
#
#    Iter9  Iter10  ...  Iter21  Iter22  Iter23  Iter24  Iter25  Iter26  Iter27  \
# 0   -inf    -inf  ...    -inf    -inf    -inf    -inf    -inf    -inf    -inf
#
#    Iter28  Iter29  Iter30
# 0    -inf    -inf    -inf
#
# [1 rows x 30 columns]

# %%
# T means transpose, it changes from row to column view, or vice versa
ackley = ackley.T
ackley
# Out:
#                     0
# Iter1  -2.963927e+137
# Iter2  -1.178570e+246
# Iter3            -inf
# Iter4            -inf
# Iter5            -inf
# Iter6            -inf
# Iter7            -inf
# Iter8            -inf
# Iter9            -inf
# Iter10           -inf
# Iter11           -inf
# Iter12           -inf
# Iter13           -inf
# Iter14           -inf
# Iter15           -inf
# Iter16           -inf
# Iter17           -inf
# Iter18           -inf
# Iter19           -inf
# Iter20           -inf
# Iter21           -inf
# Iter22           -inf
# Iter23           -inf
# Iter24           -inf
# Iter25           -inf
# Iter26           -inf
# Iter27           -inf
# Iter28           -inf
# Iter29           -inf
# Iter30           -inf

# %%
# plot the function
ackley.plot()

# %%
rastrigin
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-45-18  2022-12-12-00-45-19       0.977116
#
#        Iter1      Iter2      Iter3     Iter4      Iter5  ...    Iter21  \
# 0  166.92644  166.92644  145.32676 -6.088595 -16.791439  ... -50.40853
#
#      Iter22    Iter23    Iter24    Iter25    Iter26    Iter27    Iter28  \
# 0 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853
#
#      Iter29    Iter30
# 0 -50.40853 -50.40853
#
# [1 rows x 35 columns]

# %%
rastrigin.drop(attr,inplace=True,axis=1)

# %%
rastrigin = rastrigin.T
rastrigin
# Out:
#                  0
# Iter1   166.926440
# Iter2   166.926440
# Iter3   145.326760
# Iter4    -6.088595
# Iter5   -16.791439
# Iter6   -33.392743
# Iter7   -33.392743
# Iter8   -33.392743
# Iter9   -33.392743
# Iter10  -33.392743
# Iter11  -46.241417
# Iter12  -50.408530
# Iter13  -50.408530
# Iter14  -50.408530
# Iter15  -50.408530
# Iter16  -50.408530
# Iter17  -50.408530
# Iter18  -50.408530
# Iter19  -50.408530
# Iter20  -50.408530
# Iter21  -50.408530
# Iter22  -50.408530
# Iter23  -50.408530
# Iter24  -50.408530
# Iter25  -50.408530
# Iter26  -50.408530
# Iter27  -50.408530
# Iter28  -50.408530
# Iter29  -50.408530
# Iter30  -50.408530

# %%
rastrigin.plot()

# %%
rosenbrock
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-52-50  2022-12-12-00-52-51       0.875708
#
#           Iter1         Iter2         Iter3         Iter4         Iter5  ...  \
# 0  2.633843e+10  1.563447e+10  7.941227e+09  5.279988e+09  3.926489e+09  ...
#
#          Iter21        Iter22        Iter23        Iter24        Iter25  \
# 0  2.540964e+09  2.540917e+09  2.540888e+09  2.540872e+09  2.540865e+09
#
#          Iter26        Iter27        Iter28        Iter29        Iter30
# 0  2.540859e+09  2.540857e+09  2.540856e+09  2.540855e+09  2.540855e+09
#
# [1 rows x 35 columns]

# %%
rosenbrock.drop(attr,inplace=True,axis=1)

# %%
rosenbrock = rosenbrock.T
rosenbrock
# Out:
#                    0
# Iter1   2.633843e+10
# Iter2   1.563447e+10
# Iter3   7.941227e+09
# Iter4   5.279988e+09
# Iter5   3.926489e+09
# Iter6   3.116958e+09
# Iter7   2.876034e+09
# Iter8   2.716709e+09
# Iter9   2.625317e+09
# Iter10  2.586653e+09
# Iter11  2.564812e+09
# Iter12  2.553433e+09
# Iter13  2.547496e+09
# Iter14  2.544824e+09
# Iter15  2.543024e+09
# Iter16  2.542194e+09
# Iter17  2.541667e+09
# Iter18  2.541404e+09
# Iter19  2.541215e+09
# Iter20  2.541064e+09
# Iter21  2.540964e+09
# Iter22  2.540917e+09
# Iter23  2.540888e+09
# Iter24  2.540872e+09
# Iter25  2.540865e+09
# Iter26  2.540859e+09
# Iter27  2.540857e+09
# Iter28  2.540856e+09
# Iter29  2.540855e+09
# Iter30  2.540855e+09

# %%
rosenbrock.plot()

# %%
schwefel
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2022-12-12-00-51-48  2022-12-12-00-51-49       0.932205
#
#         Iter1       Iter2       Iter3       Iter4        Iter5  ...  \
# 0 -1661.66041 -1661.66041 -1661.66041 -1661.66041 -1661.833559  ...
#
#         Iter21       Iter22       Iter23       Iter24       Iter25  \
# 0 -1724.566212 -1724.566212 -1724.566212 -1724.566212 -1724.566212
#
#         Iter26       Iter27       Iter28       Iter29       Iter30
# 0 -1724.566212 -1724.566212 -1724.566212 -1724.566212 -1724.566212
#
# [1 rows x 35 columns]

# %%
schwefel.drop(attr,inplace=True,axis=1)

# %%
schwefel = schwefel.T
schwefel
# Out:
#                   0
# Iter1  -1661.660410
# Iter2  -1661.660410
# Iter3  -1661.660410
# Iter4  -1661.660410
# Iter5  -1661.833559
# Iter6  -1714.552148
# Iter7  -1724.566212
# Iter8  -1724.566212
# Iter9  -1724.566212
# Iter10 -1724.566212
# Iter11 -1724.566212
# Iter12 -1724.566212
# Iter13 -1724.566212
# Iter14 -1724.566212
# Iter15 -1724.566212
# Iter16 -1724.566212
# Iter17 -1724.566212
# Iter18 -1724.566212
# Iter19 -1724.566212
# Iter20 -1724.566212
# Iter21 -1724.566212
# Iter22 -1724.566212
# Iter23 -1724.566212
# Iter24 -1724.566212
# Iter25 -1724.566212
# Iter26 -1724.566212
# Iter27 -1724.566212
# Iter28 -1724.566212
# Iter29 -1724.566212
# Iter30 -1724.566212

# %%
schwefel.plot()

# %%
ackley.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
ackley = ackley.T
ackley
# Out:
#            Iter1          Iter2  Iter3  Iter4  Iter5  Iter6  Iter7  Iter8  \
# 0 -2.963927e+137 -1.178570e+246   -inf   -inf   -inf   -inf   -inf   -inf
#
#    Iter9  Iter10  ...  Iter21  Iter22  Iter23  Iter24  Iter25  Iter26  Iter27  \
# 0   -inf    -inf  ...    -inf    -inf    -inf    -inf    -inf    -inf    -inf
#
#    Iter28  Iter29  Iter30
# 0    -inf    -inf    -inf
#
# [1 rows x 30 columns]

# %%
# collect all iteration results for best fitnesses in the array
values = []

for i in range(30):
  values.append(ackley[f"Iter{i+1}"].values[0])

# %%
values=np.array(values)
values
# Out:
# array([-2.96392734e+137, -1.17856969e+246,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf,
#                    -inf,             -inf,             -inf])

# %%
# calculating standart deviation for given function
np.std(values)
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:230: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# nan

# %%
# calculating mean for given function
np.mean(values)
# Out:
# -inf

# %%
rastrigin = rastrigin.T
rastrigin
# Out:
#        Iter1      Iter2      Iter3     Iter4      Iter5      Iter6      Iter7  \
# 0  166.92644  166.92644  145.32676 -6.088595 -16.791439 -33.392743 -33.392743
#
#        Iter8      Iter9     Iter10  ...    Iter21    Iter22    Iter23  \
# 0 -33.392743 -33.392743 -33.392743  ... -50.40853 -50.40853 -50.40853
#
#      Iter24    Iter25    Iter26    Iter27    Iter28    Iter29    Iter30
# 0 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853 -50.40853
#
# [1 rows x 30 columns]

# %%
values = []

for i in range(30):
  values.append(rastrigin[f"Iter{i+1}"].values[0])

values=np.array(values)
values
# Out:
# array([166.92643994, 166.92643994, 145.32675956,  -6.088595  ,
#        -16.79143857, -33.39274337, -33.39274337, -33.39274337,
#        -33.39274337, -33.39274337, -46.24141682, -50.40853031,
#        -50.40853031, -50.40853031, -50.40853031, -50.40853031,
#        -50.40853031, -50.40853031, -50.40853031, -50.40853031,
#        -50.40853031, -50.40853031, -50.40853031, -50.40853031,
#        -50.40853031, -50.40853031, -50.40853031, -50.40853031,
#        -50.40853031, -50.40853031])

# %%
np.std(values)
# Out:
# 62.218913030734875

# %%
np.mean(values)
# Out:
# -23.822253453477504

# %%
rosenbrock = rosenbrock.T
rosenbrock
# Out:
#           Iter1         Iter2         Iter3         Iter4         Iter5  \
# 0  2.633843e+10  1.563447e+10  7.941227e+09  5.279988e+09  3.926489e+09
#
#           Iter6         Iter7         Iter8         Iter9        Iter10  ...  \
# 0  3.116958e+09  2.876034e+09  2.716709e+09  2.625317e+09  2.586653e+09  ...
#
#          Iter21        Iter22        Iter23        Iter24        Iter25  \
# 0  2.540964e+09  2.540917e+09  2.540888e+09  2.540872e+09  2.540865e+09
#
#          Iter26        Iter27        Iter28        Iter29        Iter30
# 0  2.540859e+09  2.540857e+09  2.540856e+09  2.540855e+09  2.540855e+09
#
# [1 rows x 30 columns]

# %%
values = []

for i in range(30):
  values.append(rosenbrock[f"Iter{i+1}"].values[0])

values=np.array(values)
values
# Out:
# array([2.63384263e+10, 1.56344713e+10, 7.94122717e+09, 5.27998819e+09,
#        3.92648939e+09, 3.11695834e+09, 2.87603443e+09, 2.71670896e+09,
#        2.62531670e+09, 2.58665280e+09, 2.56481156e+09, 2.55343338e+09,
#        2.54749573e+09, 2.54482435e+09, 2.54302420e+09, 2.54219401e+09,
#        2.54166738e+09, 2.54140403e+09, 2.54121472e+09, 2.54106407e+09,
#        2.54096388e+09, 2.54091702e+09, 2.54088801e+09, 2.54087224e+09,
#        2.54086529e+09, 2.54085933e+09, 2.54085700e+09, 2.54085598e+09,
#        2.54085545e+09, 2.54085506e+09])

# %%
np.std(values)
# Out:
# 4834042519.995008

# %%
np.mean(values)
# Out:
# 4130406541.670403

# %%
schwefel = schwefel.T
schwefel
# Out:
#         Iter1       Iter2       Iter3       Iter4        Iter5        Iter6  \
# 0 -1661.66041 -1661.66041 -1661.66041 -1661.66041 -1661.833559 -1714.552148
#
#          Iter7        Iter8        Iter9       Iter10  ...       Iter21  \
# 0 -1724.566212 -1724.566212 -1724.566212 -1724.566212  ... -1724.566212
#
#         Iter22       Iter23       Iter24       Iter25       Iter26  \
# 0 -1724.566212 -1724.566212 -1724.566212 -1724.566212 -1724.566212
#
#         Iter27       Iter28       Iter29       Iter30
# 0 -1724.566212 -1724.566212 -1724.566212 -1724.566212
#
# [1 rows x 30 columns]

# %%
values = []

for i in range(30):
  values.append(schwefel[f"Iter{i+1}"].values[0])

values=np.array(values)
values
# Out:
# array([-1661.66040987, -1661.66040987, -1661.66040987, -1661.66040987,
#        -1661.83355903, -1714.55214813, -1724.56621195, -1724.56621195,
#        -1724.56621195, -1724.56621195, -1724.56621195, -1724.56621195,
#        -1724.56621195, -1724.56621195, -1724.56621195, -1724.56621195,
#        -1724.56621195, -1724.56621195, -1724.56621195, -1724.56621195,
#        -1724.56621195, -1724.56621195, -1724.56621195, -1724.56621195,
#        -1724.56621195, -1724.56621195, -1724.56621195, -1724.56621195,
#        -1724.56621195, -1724.56621195])

# %%
np.std(values)
# Out:
# 23.350254826634075

# %%
np.mean(values)
# Out:
# -1713.753881111497
